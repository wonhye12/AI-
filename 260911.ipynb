# %%
print(1+2)
# Out:
# 3

# %%
print("2주차")
print(10+20)
# Out:
# 2주차
# 30

# %%
a=1
b=2
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 3
# -1
# 2
# 0.5

# %%
1 #두 자연수 10과 5가 주어진다.
2 #이때, A+B, A-B, A/B (몫), A%B(나머지)를 출력하는 프로그램을 작성하시오.
A= 10
B=5
print(A+B)
print(A-B)
print(A/B)
print(A%B)
# Out:
# 15
# 5
# 2.0
# 0

# %%
#가로 12, 세로 7인 직사각형의 넓이와 둘레를 구하시오
가로=12
세로=7
print(가로*세로)
print(2*가로+2*세로)
# Out:
# 84
# 38

# %%
#국어 88, 영어 92, 수학 75점인 학생의 과목 평균을 구하시오
국어=88
영어=92
수학=75
print((국어+영어+수학)/3)
# Out:
# 85.0
